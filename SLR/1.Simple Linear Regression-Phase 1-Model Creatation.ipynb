# %%
import pandas as pd  # importing the panda libraries to use the functions created inside

# %%
dataset = pd.read_csv("Salary_Data.csv")  # read_csv is  used to read the data from CSV file

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
independent = dataset[["YearsExperience"]] # creating the varibale to store the input values

# %%
independent
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
dependent = dataset[["Salary"]] ## creating the varibale to store the output values

# %%
dependent
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
#sklearn provides tools for splitting datasets, performing cross-validation, and tuning model parameters
from sklearn.model_selection import train_test_split # to slplit training set and test set

# %%
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=.30,random_state=0) 
# passing the input and output variable to get the test and train data an store in seperate variable
#test_size=0.3 means 30% of the data will be used for testing, and 70% for training.
# random_state=0 ensures the split is reproducible.

# %%
# here model learing proces starts
from sklearn.linear_model import LinearRegression   
regressor = LinearRegression()  # creating ad instance of the LinearRegression model from scikit-learn.
# the above two lines are procedures
regressor.fit(x_train, y_train)  # callign the fit and passing value to calculat the values
# Out:
# LinearRegression()

# %%
weight1 = regressor.coef_
weight
# Out:
# array([[9360.26128619]])

# %%
bais = regressor.intercept_

# %%
bais
# Out:
# array([26777.3913412])

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score  # this is to check the score of the model

# %%
r_score = r2_score(y_test,y_pred)

# %%
r_score # if its close to vlaue 1 then its good model
# Out:
# 0.9740993407213511

# %%
import pickle 
filename = "final_model_slr.sav"  # just creating the file to cave the model

# %%
pickle.dump(regressor, open(filename,'wb')) # This will save the model with the file name provided

# %%
loaded_model = pickle.load(open("final_model_slr.sav",'rb')) # this willload the model in particular variable

# %%
result = loaded_model.predict([[0]])  # prdicting the salary for 15 years experince
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])

# %%
result
# Out:
# array([[26777.3913412]])
